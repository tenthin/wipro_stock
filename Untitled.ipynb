# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv("Wipro_Limitedstock.csv")
dt.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close  \
# 0  2001-01-24  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780
# 1  2001-01-25  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213
# 2  2001-01-26  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227
# 3  2001-01-29  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357
# 4  2001-01-30  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004
#
#          Company
# 0  Wipro Limited
# 1  Wipro Limited
# 2  Wipro Limited
# 3  Wipro Limited
# 4  Wipro Limited

# %%
dt.drop('Company', axis = 'columns', inplace = True)

# %%
dt
# Out:
#             Date      High       Low      Open     Close     Volume  Adj Close
# 0     2001-01-24  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780
# 1     2001-01-25  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213
# 2     2001-01-26  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227
# 3     2001-01-29  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357
# 4     2001-01-30  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004
# ...          ...       ...       ...       ...       ...        ...        ...
# 5026  2021-01-15  6.420000  6.330000  6.420000  6.390000  2482000.0   6.376404
# 5027  2021-01-19  6.350000  6.270000  6.350000  6.330000  2760000.0   6.316532
# 5028  2021-01-20  6.580000  6.460000  6.460000  6.570000  2674500.0   6.556022
# 5029  2021-01-21  6.590000  6.480000  6.560000  6.580000  2456700.0   6.566000
# 5030  2021-01-22  6.560000  6.480000  6.490000  6.550000  2035400.0   6.550000
#
# [5031 rows x 7 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5031 entries, 0 to 5030
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5031 non-null   object
#  1   High       5031 non-null   float64
#  2   Low        5031 non-null   float64
#  3   Open       5031 non-null   float64
#  4   Close      5031 non-null   float64
#  5   Volume     5031 non-null   float64
#  6   Adj Close  5031 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 275.3+ KB

# %%
dt.mean(axis = 0)
# Out:
# High         4.081117e+00
# Low          3.979558e+00
# Open         4.031290e+00
# Close        4.031329e+00
# Volume       1.484391e+06
# Adj Close    3.789482e+00
# dtype: float64

# %%
dt[["day", "month", "year"]] = dt["Date"].str.split("-", expand = True)

# %%
dt.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close  \
# 0  2001-01-24  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780
# 1  2001-01-25  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213
# 2  2001-01-26  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227
# 3  2001-01-29  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357
# 4  2001-01-30  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004
#
#     day month year
# 0  2001    01   24
# 1  2001    01   25
# 2  2001    01   26
# 3  2001    01   29
# 4  2001    01   30

# %%
dt.rename(columns={'day':'Year','year':'Day'},inplace = True)

# %%
dt.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close  \
# 0  2001-01-24  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780
# 1  2001-01-25  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213
# 2  2001-01-26  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227
# 3  2001-01-29  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357
# 4  2001-01-30  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004
#
#    Year month Day
# 0  2001    01  24
# 1  2001    01  25
# 2  2001    01  26
# 3  2001    01  29
# 4  2001    01  30

# %%
dt.drop(['Date','month','Day'],axis = 'columns',inplace = True)

# %%
dt.head()
# Out:
#        High       Low      Open     Close     Volume  Adj Close  Year
# 0  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780  2001
# 1  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213  2001
# 2  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227  2001
# 3  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357  2001
# 4  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004  2001

# %%
g = dt.groupby('Year')

# %%
g.head()
# Out:
#           High       Low      Open     Close     Volume  Adj Close  Year
# 0     2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780  2001
# 1     2.768176  2.698483  2.768176  2.701271   356478.0   2.324213  2001
# 2     2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227  2001
# 3     2.680642  2.631579  2.671722  2.656111   715198.0   2.285357  2001
# 4     2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004  2001
# ...        ...       ...       ...       ...        ...        ...   ...
# 5017  5.810000  5.670000  5.780000  5.730000  1905400.0   5.717809  2021
# 5018  5.960000  5.860000  5.880000  5.880000  2811800.0   5.867489  2021
# 5019  6.120000  5.840000  5.870000  6.070000  3956800.0   6.057086  2021
# 5020  6.010000  5.910000  6.000000  5.960000  1804800.0   5.947319  2021
# 5021  6.320000  6.220000  6.240000  6.300000  2501400.0   6.286596  2021
#
# [105 rows x 7 columns]

# %% [markdown]
# ## To print all the years in differnt dataframe

# %%
for Year,year_dt in g:
    print(Year)
    print(year_dt)
# Out:
# 2001
#          High       Low      Open     Close     Volume  Adj Close  Year
# 0    2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780  2001
# 1    2.768176  2.698483  2.768176  2.701271   356478.0   2.324213  2001
# 2    2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227  2001
# 3    2.680642  2.631579  2.671722  2.656111   715198.0   2.285357  2001
# 4    2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004  2001
# ..        ...       ...       ...       ...        ...        ...   ...
# 228  1.694915  1.685995  1.692685  1.692685   150214.0   1.456411  2001
# 229  1.688225  1.645852  1.688225  1.645852   311638.0   1.416115  2001
# 230  1.610616  1.508475  1.610616  1.545495  1914668.0   1.329767  2001
# 231  1.623550  1.561998  1.572257  1.605709  1194986.0   1.381575  2001
# 232  1.672614  1.621320  1.654773  1.632471  1033562.0   1.404602  2001
#
# [233 rows x 7 columns]
# 2002
# ...

# %% [markdown]
# ## To get specific data frame for each Year

# %%
one = g.get_group('2001')

# %%
one
# Out:
#        High       Low      Open     Close     Volume  Adj Close  Year
# 0  2.809991  2.706847  2.706847  2.768176  2044704.0   2.381780  2001
# 1  2.768176  2.698483  2.768176  2.701271   356478.0   2.324213  2001
# 2  2.676182  2.598127  2.651093  2.673394  1376588.0   2.300227  2001
# 3  2.680642  2.631579  2.671722  2.656111   715198.0   2.285357  2001
# 4  2.832293  2.720785  2.743087  2.720785  1751002.0   2.341004  2001

# %% [markdown]
# ## Getting maximum values of each column

# %%
maximum = g.max()
maximum
# Out:
#           High       Low      Open     Close      Volume  Adj Close
# Year
# 2001  2.888046  2.811775  2.821142  2.814451   9658536.0   2.421595
# 2002  1.962533  1.855486  1.922391  1.929081   4331544.0   1.659810
# 2003  2.185549  2.140946  2.182872  2.171722   7934438.0   1.868899
# 2004  3.438894  3.358608  3.416146  3.414808  11317616.0   2.979818
# 2005  3.412132  3.347904  3.393399  3.366637   7361233.0   2.953949
# 2006  4.386262  4.308653  4.375558  4.343443   4602452.0   3.847349
# 2007  4.934880  4.849242  4.926851  4.902765   4845709.0   4.342788
# 2008  4.011597  3.834969  4.011597  3.888492   6240233.0   3.485839
# 2009  6.155219  6.024086  6.155219  6.107047   9337183.0   5.558104
# 2010  7.497770  7.283675  7.439786  7.479929  12896731.0   6.852401
# 2011  7.038359  6.935772  6.966994  6.998216   5450975.0   6.411101
# 2012  5.124888  5.057984  5.098127  5.115968   3463442.0   4.752485
# 2013  6.330000  6.260000  6.300000  6.305000   3915429.0   6.007818
# ...

# %% [markdown]
# ## Getting minimum values of each column

# %%
minimum = g.min()
minimum
# Out:
#           High       Low      Open     Close     Volume  Adj Close
# Year
# 2001  0.825156  0.757806  0.820696  0.757806    58292.0   0.652027
# 2002  1.011151  0.991079  0.995986  0.991079    22420.0   0.852883
# 2003  0.830508  0.815343  0.816236  0.824710    49324.0   0.709713
# 2004  1.707850  1.553524  1.576717  1.677074   298933.0   1.463443
# 2005  2.435326  2.353702  2.393845  2.365745   353862.0   2.064389
# 2006  2.836753  2.724353  2.724353  2.769848   308275.0   2.430316
# 2007  3.559322  3.342551  3.428189  3.436218   502582.0   3.080399
# 2008  1.672614  1.514719  1.608385  1.530776   629255.0   1.383806
# 2009  1.469224  1.348796  1.367529  1.375558   561995.0   1.243490
# 2010  5.269402  5.041927  5.140946  5.173060   240118.0   4.708071
# 2011  4.032114  3.849242  3.893845  3.956289   383382.0   3.661613
# 2012  3.492417  3.371989  3.429973  3.412132   216577.0   3.196864
# 2013  3.570000  3.455000  3.540000  3.520000   281800.0   3.311229
# ...

# %%
average = g.mean()
average
# Out:
#           High       Low      Open     Close        Volume  Adj Close
# Year
# 2001  1.541244  1.481942  1.511834  1.511304  2.038401e+06   1.300349
# 2002  1.441597  1.410332  1.425423  1.426494  8.340863e+05   1.227472
# 2003  1.314432  1.276282  1.293070  1.295154  1.728546e+06   1.114558
# 2004  2.371970  2.292874  2.334394  2.329418  2.312564e+06   2.024236
# 2005  2.827577  2.756574  2.796605  2.793668  1.623282e+06   2.444703
# 2006  3.682746  3.577213  3.631003  3.628732  1.350836e+06   3.199655
# 2007  4.224401  4.096659  4.170334  4.158264  1.631890e+06   3.708064
# 2008  2.981838  2.822335  2.901024  2.904683  2.366189e+06   2.613645
# 2009  3.554065  3.410688  3.474980  3.490432  1.964640e+06   3.169881
# 2010  6.180200  6.012677  6.104481  6.097571  1.378769e+06   5.570428
# 2011  5.461500  5.314876  5.394029  5.382436  1.428566e+06   4.960991
# 2012  4.171829  4.079269  4.126476  4.126673  9.628081e+05   3.847884
# ...

# %%
g.describe()
# Out:
#        High                                                              \
#       count      mean       std       min       25%       50%       75%
# Year
# 2001  233.0  1.541244  0.493982  0.825156  1.238626  1.460749  1.659233
# 2002  252.0  1.441597  0.218007  1.011151  1.260370  1.471677  1.595004
# 2003  252.0  1.314432  0.317002  0.830508  1.037356  1.306646  1.527989
# 2004  252.0  2.371970  0.478887  1.707850  2.005910  2.188001  2.672837
# 2005  252.0  2.827577  0.190325  2.435326  2.708631  2.811998  2.942796
# 2006  251.0  3.682746  0.330386  2.836753  3.406780  3.727921  3.936664
# 2007  251.0  4.224401  0.312528  3.559322  3.991525  4.252453  4.434433
# 2008  253.0  2.981838  0.554698  1.672614  2.609277  3.125781  3.366637
# 2009  252.0  3.554065  1.362029  1.469224  2.271410  3.361284  4.748216
# 2010  252.0  6.180200  0.457248  5.269402  5.842105  6.155219  6.479706
# 2011  252.0  5.461500  0.904650  4.032114  4.503791  5.820696  6.199822
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# C:\Users\tenth\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Year
# 2001    AxesSubplot(0.125,0.125;0.775x0.755)
# 2002    AxesSubplot(0.125,0.125;0.775x0.755)
# 2003    AxesSubplot(0.125,0.125;0.775x0.755)
# 2004    AxesSubplot(0.125,0.125;0.775x0.755)
# 2005    AxesSubplot(0.125,0.125;0.775x0.755)
# 2006    AxesSubplot(0.125,0.125;0.775x0.755)
# 2007    AxesSubplot(0.125,0.125;0.775x0.755)
# 2008    AxesSubplot(0.125,0.125;0.775x0.755)
# 2009    AxesSubplot(0.125,0.125;0.775x0.755)
# 2010    AxesSubplot(0.125,0.125;0.775x0.755)
# 2011    AxesSubplot(0.125,0.125;0.775x0.755)
# 2012    AxesSubplot(0.125,0.125;0.775x0.755)
# ...
